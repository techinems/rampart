# %%
import requests
import json
import pprint

url = 'http://express_backend:3000/users/'
headers = {'content-type': 'application/json'}

result = requests.get(url)
pprint.pprint(result.json())
# Out:
# [{'access_revoked': False,
#   'active': True,
#   'admin': True,
#   'created': '2020-03-25T01:42:02.402Z',
#   'created_by': 0,
#   'dob': '1998-08-26',
#   'email': 'may7@rpi.edu',
#   'first_name': 'Yuze',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 0,
#   'last_login': None,
#   'last_name': 'Ma',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '123456',
#   'phone': '5189772963',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': None,
#   'updated_by': None},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T01:44:02.866Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 1,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T01:44:02.866Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T01:44:05.395Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 2,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T01:44:05.395Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T02:07:32.011Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 3,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T02:07:32.011Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T02:27:44.867Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 4,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T02:27:44.867Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T02:27:55.392Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 5,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T02:27:55.392Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T03:10:11.597Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 6,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T03:10:11.597Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T03:10:22.979Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 7,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T03:10:22.979Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T03:13:04.186Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 8,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T03:13:04.186Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T03:13:51.858Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 9,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T03:13:51.858Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T05:10:21.987Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 10,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T05:10:21.987Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T05:11:18.506Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 11,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T05:11:18.506Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T05:11:55.012Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 12,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T05:11:55.012Z',
#   'updated_by': 0},
#  {'access_revoked': False,
#   'active': True,
#   'admin': False,
#   'created': '2020-03-25T05:18:03.303Z',
#   'created_by': 0,
#   'dob': '2020-03-25',
#   'email': 'foo.bar@bar.foo',
#   'first_name': 'First',
#   'g_id': None,
#   'home_city': None,
#   'home_state': None,
#   'home_street': None,
#   'home_zip': None,
#   'id': 13,
#   'last_login': None,
#   'last_name': 'Last',
#   'local_city': None,
#   'local_state': None,
#   'local_street': None,
#   'local_zip': None,
#   'nine_hundred': None,
#   'password': '1234567',
#   'phone': '1234567890',
#   'rcs_id': None,
#   'rin': None,
#   'slack_id': None,
#   'updated': '2020-03-25T05:18:03.303Z',
#   'updated_by': 0}]
